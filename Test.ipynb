# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from scipy.misc import imread, imresize

# %% [markdown]
# # Small

# %%
hf_prob_small = imread('hf_prob-small.ppm')
hf_prob_ref_small = imread('hf_prob_ref-small.ppm')
plt.subplot(121)
plt.imshow(hf_prob_small)
plt.subplot(122)
plt.imshow(hf_prob_ref_small)

# %%
print hf_prob_small.min(), hf_prob_small.max()
print hf_prob_ref_small.min(), hf_prob_ref_small.max()
# Out:
# 0 255
# 0 255

# %%
hf_tgt_small = imread('hf_tgt-small.ppm')
hf_tgt_ref_small = imread('hf_tgt_ref-small.ppm')
plt.subplot(121)
plt.imshow(hf_tgt_small)
plt.subplot(122)
plt.imshow(hf_tgt_ref_small)

# %%
print hf_tgt_small.min(), hf_tgt_small.max()
print hf_tgt_ref_small.min(), hf_tgt_ref_small.max()
# Out:
# 0 255
# 0 255

# %%
grad_small = imread('grad-small.ppm')
grad_ref_small = imread('grad_ref-small.ppm')
plt.subplot(121)
plt.imshow(grad_small)
plt.subplot(122)
plt.imshow(grad_ref_small)

# %%
print grad_small[0]
# Out:
# [ 37  82  81  78  77  79  78  79  79  79  79  80  80  81  82  85  86  84
#   83  86  85  86  90  90  91  93  94  94  95 101 105 106 110 115 121 124
#  131 142 159 184 208 219 222 213 192 182 179 182 192 199 200 208 204 173
#  173 161 151 148 147 157 170 179 169 151 135 121 114 110 104  95  91  86
#   84  90  88  73  66 105 119 120]

# %% [markdown]
# # Original

# %%
hf_prob = imread('hf_prob.ppm')
grad = imread('grad.ppm')

# %%
plt.subplot(121)
plt.imshow(imresize(hf_prob, (240, 180)))
plt.subplot(122)
plt.imshow(imresize(grad, (200, 200)))
